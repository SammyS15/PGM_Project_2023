# %%
import pandas as pd
import numpy as np

#Load in snia
# /Users/sammysharief/Downloads/PGM-Project/SNIa_sims.csv
import os
# print(os.getcwd())
snia = pd.read_csv("./SNIa_sims.csv", index_col=0)
snibc = pd.read_csv("./SNIbc_sims.csv", index_col=0)
snii = pd.read_csv("./SNII_sims.csv", index_col=0)

#Combine into one big dataframe
df = pd.concat([snia, snibc, snii])

#Save to csv
df.to_csv("./all_sims.csv")

# %%
snia
# Out:
#                X_villar_fit_amplitude  X_villar_fit_baseline  \
# ObjectID
# _4877922_SNIa            34272.580547          -14975.148816
# _1309355_SNIa           235393.539892             335.466275
# _3053534_SNIa             3526.531174              54.987832
# _3315509_SNIa             2980.452946             121.692428
# _4109434_SNIa            25998.374006             525.868638
# ...                               ...                    ...
# _2303364_SNIa            60022.039086            -350.504038
# _4431841_SNIa            19349.472036           -8387.347804
# _3414162_SNIa            23812.087466          -14606.302566
# _4011245_SNIa            18171.229880             795.587435
# _2226248_SNIa             6347.398372             446.695799
#
#                X_villar_fit_peak_time  X_villar_fit_rise_time  \
# ObjectID
# _4877922_SNIa            58863.288714            1.324928e+01
# _1309355_SNIa            58528.400701            3.037857e+09
# ...

# %%
snibc
# Out:
#                     X_villar_fit_amplitude  X_villar_fit_baseline  \
# ObjectID
# PALE_3861766_SNIbc             6947.852239             329.712891
# PALE_92639_SNIbc               8469.227442             433.940083
# PALE_1044170_SNIbc             2418.177659             516.479174
# PALE_4311714_SNIbc            44832.134340           -5807.043189
# PALE_297863_SNIbc             10222.205201             355.115219
# ...                                    ...                    ...
# PALE_4069818_SNIbc            12813.324987            1860.135727
# PALE_4821142_SNIbc            76250.991531            -710.101910
# PALE_4072089_SNIbc             8155.391633             869.946482
# PALE_4532920_SNIbc             4585.135197            -134.511935
# PALE_4134040_SNIbc           125350.176360            1119.698454
#
#                     X_villar_fit_peak_time  X_villar_fit_rise_time  \
# ObjectID
# PALE_3861766_SNIbc            59191.185394            2.592961e+08
# ...

# %%
snii
# Out:
#                    X_villar_fit_amplitude  X_villar_fit_baseline  \
# ObjectID
# PALE_2583690_SNII             4016.354100             535.357947
# PALE_1934451_SNII             3375.582191            -121.877186
# PALE_1270642_SNII             1731.820626              16.259680
# PALE_3675724_SNII              392.319810             264.764517
# PALE_506793_SNII              8090.151629           -2475.094883
# ...                                   ...                    ...
# PALE_3375800_SNII            16591.895611             351.745712
# PALE_2987580_SNII             2931.460257              39.368020
# PALE_3295167_SNII             3435.939120             -76.893243
# PALE_1595765_SNII             7452.200579              46.672356
# PALE_791176_SNII              1919.066945             340.071056
#
#                    X_villar_fit_peak_time  X_villar_fit_rise_time  \
# ObjectID
# PALE_2583690_SNII            58770.802808              151.485077
# ...
